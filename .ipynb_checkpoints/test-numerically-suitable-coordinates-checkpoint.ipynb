# %%
from functions_bending_schreyer_adaptive89 import *
import matplotlib.pyplot as plt
from mpmath import mpmathify
import mpmath as mp
import numpy as np
import math
import time
from scipy.interpolate import CubicSpline
from rungekuttacoefficients import *

# %%
print("Main!")
L = 0.1
wh = 0.001
def hsc(s):
    return 0.2 # + (s - L/2)**2 * 4

def h(s):
    return wh * hsc(s)

alpap = np.sqrt(0.1/10**10/(h(0)**3 * 0.001/12))
s_eval = mp.matrix(np.linspace(0,L,int(200),endpoint = True))
#compare_coordinates_schemes(grid, hspline, thickness=1, E=1, Fweight=mpmathify(1), m0 = 1, Fs=1, tol=0.001, use89=False):
m0 =  0.0001#mpmathify("1E-12000")

bend_to_y_theta(s_eval, h, thickness=mpmathify(0.001), E=mpmathify(10**10), Fweight=mpmathify(0.1), y0 = L * 0.001, theta0 = 0.01, tol=0.000001, use89=True)

# %%
print("Main!")
L = 0.1
wh = 0.001
def hsc(s):
    return 0.2 # + (s - L/2)**2 * 4

def h(s):
    return wh * hsc(s)
s_eval = mp.matrix(np.linspace(0,L,int(200),endpoint = True))
ret = bend_theta_y(s_eval, h, thickness=mpmathify(0.001), E=mpmathify(10**10), Fweight=mpmathify(0.1), y0 = mpmathify(0.006), theta0=mpmathify(0.1), tol=0.000001, use89=True)
# Out:
# Main!
# STARTING!(IC):  [1.0e-12000]
# [       0.0]
# [       0.0]
# [       0.0]
# LOOP 89
# DONE 89
# STARTING!(IC):  [       0.0]
# [       0.0]
# [1.0e-12000]
# [       0.0]
# LOOP 89
# DONE 89
# [[mpf('5.5187653694178376e+164'), mpf('1.3495896833532471e+168')], [mpf('2.1374086367381507e+168'), mpf('5.2269383678404661e+171')]]
# mat 3872.98334620742 3872.98334620742 DET: 0
# -3.95316900990841e+320
# STARTING!(IC):  [1.0e-12000]
# [       0.0]
# [       0.0]
# [       0.0]
# LOOP 89
# 1000 0.0101523259758335
# 2000 0.0109873677911683
# 3000 0.0120467528007372
# 4000 0.0130208167879772
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 10
#       8     return wh * hsc(s)
#       9 s_eval = mp.matrix(np.linspace(0,L,int(200),endpoint = True))
# ---> 10 ret = bend_theta_y(s_eval, h, thickness=mpmathify(0.001), E=mpmathify(10**10), Fweight=mpmathify(0.1), y0 = mpmathify(0.006), theta0=mpmathify(0.1), tol=0.000001, use89=True)
#
# File ~\Documents\GitHub\BeamBending\functions_bending_schreyer_adaptive89.py:566, in bend_theta_y(grid, hspline, thickness, E, Fweight, y0, theta0, tol, use89)
#     564 #Matrix entries for small initial moment
#     565 f0 = mp.matrix([mpmathify("1E" +  str(min_exponent)), mpmathify(0), mpmathify(0), mpmathify(0)])
# --> 566 S, F, Es = bend(
#     567     f0, s0, grid[len(grid) - 1], df_ds_tran, tol, grid[1] - grid[0]
#     568 )
#     569 mat[0][1] = F[-1][2]/mpmathify("1E" +  str(min_exponent))
#     570 mat[1][1] = F[-1][1]/mpmathify("1E" +  str(min_exponent))
#
# File ~\Documents\GitHub\BeamBending\functions_bending_schreyer_adaptive89.py:172, in mp_RKF89_adaptive(f0, s0, s_final, dfds, step_tol, ds_max)
#     170 fa = f
#     171 for i in range(0, k):
# --> 172     fa = fa + ks[i] * Bkl[k, i]
#     174 ks[k] = ds * dfds(args_s[k], fa)
#     175 if k in [0,14,15,16]:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mpmath\matrices\matrices.py:651, in _matrix.__add__(self, other)
#     649 new = self.ctx.matrix(self.__rows, self.__cols)
#     650 for i in xrange(self.__rows):
# --> 651     for j in xrange(self.__cols):
#     652         new[i,j] = self[i,j] + other[i,j]
#     653 return new
#
# KeyboardInterrupt:

# %%
ret[0]#3.8e3

# %%
(ret[-1])

# %%
mp.det(mp.matrix(ret[0]))

# %%
M = ret[0]
M[0][0] * M[1][1] - M[1][0] * M[0][1]

# %%
M = ret[1]
M[0][0] * M[1][1] - M[1][0] * M[0][1]

# %%
print("Main!")
L = 0.1
wh = 0.001
def hsc(s):
    return 0.2 # + (s - L/2)**2 * 4

def h(s):
    return wh * hsc(s)

alpap = np.sqrt(0.1/10**10/(h(0)**3 * 0.001/12))
s_eval = mp.matrix(np.linspace(0,L,int(200),endpoint = True))
#compare_coordinates_schemes(grid, hspline, thickness=1, E=1, Fweight=mpmathify(1), m0 = 1, Fs=1, tol=0.001, use89=False):
m0 =  0.0001#mpmathify("1E-12000")

bend_to_y_theta(s_eval, h, thickness=mpmathify(0.001), E=mpmathify(10**10), Fweight=mpmathify(0.1), y0 = L * 0.001, theta0 = 0.01, tol=0.000001, use89=True)
              
sa, sb, a, b = compare_coordinates_schemes(s_eval, h, thickness=mpmathify(0.001), E=mpmathify(10**10), Fweight=mpmathify(0.1), m0 = m0, Fs = m0 /alpap, tol=0.001, use89=True)
# Out:
# Main!
# STARTING!(IC):  [1.0e-12000]
# [       0.0]
# [       0.0]
# [       0.0]
# LOOP 89
# DONE 89
# STARTING!(IC):  [       0.0]
# [       0.0]
# [1.0e-12000]
# [       0.0]
# LOOP 89
# DONE 89
# STARTING!(IC):  [1.0e-12000]
# [       0.0]
# [       0.0]
# [       0.0]
# LOOP 89
# DONE 89
# STARTING!(IC):  [       0.0]
# [       0.0]
# [       0.0]
# [1.0e-12000]
# LOOP 89
# DONE 89
# 34013.2669625898 DETERMINANT!
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# DONE 89
# 1.6771745501094e-15 <class 'mpmath.ctx_mp_python.mpf'>
# STARTING!(IC):  [-4.50033467398658e-6]
# [                 0.0]
# [                 0.0]
# [0.000227108988962377]
# LOOP 89
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 15
#      12 #compare_coordinates_schemes(grid, hspline, thickness=1, E=1, Fweight=mpmathify(1), m0 = 1, Fs=1, tol=0.001, use89=False):
#      13 m0 =  0.0001#mpmathify("1E-12000")
# ---> 15 bend_to_y_theta(s_eval, h, thickness=mpmathify(0.001), E=mpmathify(10**10), Fweight=mpmathify(0.1), y0 = L * 0.001, theta0 = 0.01, tol=0.000001, use89=True)
#      17 sa, sb, a, b = compare_coordinates_schemes(s_eval, h, thickness=mpmathify(0.001), E=mpmathify(10**10), Fweight=mpmathify(0.1), m0 = m0, Fs = m0 /alpap, tol=0.001, use89=True)
#
# File ~\Documents\GitHub\BeamBending\functions_bending_schreyer_adaptive89.py:257, in bend_to_y_theta(grid, hspline, thickness, E, Fweight, y0, theta0, tol, use89)
#     254 Fs_sol = guess[0] * (1 + (i - N//2)/N*8 )
#     255 M0_sol = guess[1] * (1 + (j - M//2)/M*8 )
# --> 257 res = objective1(Fs_sol,M0_sol)**2 + objective2(Fs_sol,M0_sol)**2
#     258 Fss.append(Fs_sol)
#     259 M0ss.append(M0_sol)
#
# File ~\Documents\GitHub\BeamBending\functions_bending_schreyer_adaptive89.py:240, in bend_to_y_theta.<locals>.objective1(Fs, m0)
#     239 def objective1(Fs, m0):
# --> 240     S, F, Es = bend_alt_cor(a, grid, hspline, thickness, E, Fweight, guess[1], guess[0], tol, use89)
#     242     resu = mp.matrix([[F[-1][2]], [F[-1][1]]])
#     243     return ((target[0] - resu[0])/L)
#
# File ~\Documents\GitHub\BeamBending\functions_bending_schreyer_adaptive89.py:335, in bend_alt_cor(atransform, grid, hspline, thickness, E, Fweight, m0, Fs, tol, use89)
#     331 s0 = grid[0]
#     334 f0 = mp.matrix([m0, mpmathify(0), mpmathify(0), Fs])
# --> 335 S, F, Es = bend(
#     336     f0, s0, grid[len(grid) - 1], df_ds_tran, tol, grid[1] - grid[0]
#     337 )
#     339 #transform back to y, theta coordinates
#     340 #gp=[mp.matrix([[-1, L],[atransform, -1]])**-1 * mp.matrix([[F[i][2]],[F[i][1]]]) for i in range(len(F))]
#     342 return S, F, Es
#
# File ~\Documents\GitHub\BeamBending\functions_bending_schreyer_adaptive89.py:174, in mp_RKF89_adaptive(f0, s0, s_final, dfds, step_tol, ds_max)
#     171 for i in range(0, k):
#     172     fa = fa + ks[i] * Bkl[k, i]
# --> 174 ks[k] = ds * dfds(args_s[k], fa)
#     175 if k in [0,14,15,16]:
#     176     if k == 0:
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mpmath\matrices\matrices.py:605, in _matrix.__rmul__(self, other)
#     603 if isinstance(other, self.ctx.matrix):
#     604     raise TypeError("other should not be type of ctx.matrix")
# --> 605 return self.__mul__(other)
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\mpmath\matrices\matrices.py:595, in _matrix.__mul__(self, other)
#     593 for i in xrange(self.__rows):
#     594     for j in xrange(self.__cols):
# --> 595         new[i, j] = other * self[i, j]
#     596 return new
#
# File <string>:5, in __mul__(self, other)
#
# KeyboardInterrupt:

# %%
print(a[-1], b[-1])

# %%
x,z = (integrate_xz(mp.matrix([a[i][1] for i in range(len(a))]), sa))
x2,z2 = (integrate_xz(mp.matrix([b[i][1] for i in range(len(b))]), sb))

# %%
plt.plot(z2,x2)
plt.scatter(z,x, c= 'r')
